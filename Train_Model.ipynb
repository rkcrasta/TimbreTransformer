# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Directory of the python scripts that need to be imported - passed to sys.path.append()
SCRIPTS_PATH = '/content/drive/My Drive/TimbreTransformer/Scripts'

# %%
#The working directory passed to os.chdir()
DEFAULT_PATH = '/content/drive/My Drive/TimbreTransformer'

# %%
TRAIN_PARAMS = {'model_name':'flute_v1', 'target_audio':['Data/Flute.mp3'], 'train_audio':['Data/Violin.mp3','Data/Piano.mp3', 'Data/Guitar.mp3', 'Data/Cello.mp3']}

# %%
import sys
sys.path.append(SCRIPTS_PATH)
import os
os.chdir(DEFAULT_PATH)

# %%
import import_audio
import process_audio
import custom_loss
import tensorflow as tf
import numpy as np
import model
import json

# %%
gan = model.Model(TRAIN_PARAMS['model_name']).load_from_file()

# %% [markdown]
# # Load Data

# %%
#Creates list of Audio objects that the network aims to sound like
target_audio = [import_audio.Audio(file, n_fft=gan.model_params['n_fft'], srate=gan.model_params['srate'], shuffle_spec = True, shuffle_audio = True) for file in TRAIN_PARAMS['target_audio']]
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
#Creates list of Audio objects that the network aims to transform
train_audio =  [import_audio.Audio(file,n_fft=gan.model_params['n_fft'], srate=gan.model_params['srate']) for file in TRAIN_PARAMS['train_audio']]
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %% [markdown]
# # Load Model

# %%
def train(model, n_epochs = 10, n_batches = 10):

    #The accuracy of the generator model. Will skip training the discriminator when the generator has less than 0.50 accuracy
    gan_accuracy = 1

    loss_ratio = 1

    for i in range(n_epochs):
        print('Epoch: ', i+1,)

        if gan_accuracy <= 0.5:
            print("Generator accuracy is less than 50%, skipping discriminator training for current epoch")

        else:
            
            #This is the batch size that the partition function will create for each Audio object in target_audio and train_audio
            #The total batch size of the training data will be batch_size * len(target_audio), which is approximately equal to n_batches
            target_batch_size = int(n_batches/len(target_audio))
            training_batch_size = int(n_batches/len(train_audio))

            #Get real data from target_audio. This will be the data that the gan will train to emulate
            X_real = np.expand_dims(np.concatenate([process_audio.partition(audio.ft.spec, randomize=True, batch_size = target_batch_size, input_shape=model.input_shape)[0] for audio in target_audio], axis = 0), axis = -1)
            
            #Label the real data as 1
            y_real = np.array([1]*X_real.shape[0])


            
            #The data that will be passed to the generator. The generator will try to transform this data to make it sound like the target_audio
            X_gen = np.expand_dims(np.concatenate([process_audio.partition(audio.ft.spec, randomize=True, batch_size = training_batch_size, input_shape=model.input_shape)[0] for audio in train_audio], axis = 0), axis = -1)
            
            X_fake = model.generator.predict(X_gen)
            
            #Label the fake data as 0
            y_fake = np.array([0]*X_fake.shape[0])

            X = np.concatenate((X_real, X_fake), axis = 0)
            y = np.concatenate((y_real, y_fake), axis = 0)

            print('Training Discriminator')

            #keras fit() method returns a History object that contains the final loss values. 
            #This will be used to balance the training of the generator and discriminator 
            disc_history = model.discriminator.fit(X, y)

            disc_loss = disc_history.history['loss'][0]

        if (loss_ratio >= 2):

            print('Discriminator loss is more than 2x the generator loss, skipping generator training for current epoch')

        else:

            training_batch_size = int(n_batches/len(train_audio))

            #The input for training the gan. The model will try to transform this data and use the discriminator to judge how well it emulates the target_audio samples.
            #The discriminator does not train during this step
            X_gan = np.expand_dims(np.concatenate([process_audio.partition(audio.ft.spec, randomize=True, batch_size = training_batch_size, input_shape=model.input_shape)[0] for audio in train_audio], axis = 0), axis = -1)

            #Setting the y values to 1 makes the model try to emulate the target_audio. This will result in a higher loss if the discriminator judges the output as fake.
            y_gan = np.array([1]*X_gan.shape[0])

            print('Training Gan')


            gan_history = model.model.fit(X_gan, [y_gan, X_gan])

        gan_loss = gan_history.history['discriminator_loss'][0]
        gan_accuracy = gan_history.history['discriminator_binary_accuracy'][0]


        try:
            loss_ratio = disc_loss/gan_loss

        except:
            loss_ratio = 2

# %%
train(gan,n_epochs = 500, n_batches = 1000)
# Out:
# Epoch:  1
# Training Discriminator
# 63/63 [==============================] - 1s 10ms/step - loss: 1.1575e-04 - binary_accuracy: 1.0000
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.6887 - discriminator_loss: 15.0260 - tf.math.multiply_32_loss: 3.6627 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  2
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.6039 - discriminator_loss: 14.9517 - tf.math.multiply_32_loss: 3.6522 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  3
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 42ms/step - loss: 18.4871 - discriminator_loss: 14.9324 - tf.math.multiply_32_loss: 3.5547 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  4
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4996 - discriminator_loss: 14.9413 - tf.math.multiply_32_loss: 3.5583 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  5
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 42ms/step - loss: 18.5009 - discriminator_loss: 14.9416 - tf.math.multiply_32_loss: 3.5593 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  6
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4587 - discriminator_loss: 14.9270 - tf.math.multiply_32_loss: 3.5317 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  7
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3327 - discriminator_loss: 14.8980 - tf.math.multiply_32_loss: 3.4347 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  8
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4802 - discriminator_loss: 14.9113 - tf.math.multiply_32_loss: 3.5689 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  9
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.5858 - discriminator_loss: 14.9443 - tf.math.multiply_32_loss: 3.6414 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  10
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4787 - discriminator_loss: 14.9104 - tf.math.multiply_32_loss: 3.5683 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  11
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 42ms/step - loss: 18.5042 - discriminator_loss: 14.9056 - tf.math.multiply_32_loss: 3.5986 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  12
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 42ms/step - loss: 18.4778 - discriminator_loss: 14.9037 - tf.math.multiply_32_loss: 3.5741 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  13
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4984 - discriminator_loss: 14.9109 - tf.math.multiply_32_loss: 3.5876 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  14
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.5012 - discriminator_loss: 14.9059 - tf.math.multiply_32_loss: 3.5952 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  15
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.5060 - discriminator_loss: 14.9329 - tf.math.multiply_32_loss: 3.5731 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  16
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4675 - discriminator_loss: 14.9176 - tf.math.multiply_32_loss: 3.5499 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  17
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 42ms/step - loss: 18.3459 - discriminator_loss: 14.8951 - tf.math.multiply_32_loss: 3.4508 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  18
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4597 - discriminator_loss: 14.9103 - tf.math.multiply_32_loss: 3.5493 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  19
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3734 - discriminator_loss: 14.8972 - tf.math.multiply_32_loss: 3.4762 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  20
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4230 - discriminator_loss: 14.8976 - tf.math.multiply_32_loss: 3.5254 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  21
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4463 - discriminator_loss: 14.8874 - tf.math.multiply_32_loss: 3.5588 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  22
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4236 - discriminator_loss: 14.9116 - tf.math.multiply_32_loss: 3.5120 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  23
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4264 - discriminator_loss: 14.9167 - tf.math.multiply_32_loss: 3.5096 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  24
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4360 - discriminator_loss: 14.8970 - tf.math.multiply_32_loss: 3.5390 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  25
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4731 - discriminator_loss: 14.8960 - tf.math.multiply_32_loss: 3.5771 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  26
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4184 - discriminator_loss: 14.8971 - tf.math.multiply_32_loss: 3.5213 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  27
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4510 - discriminator_loss: 14.8985 - tf.math.multiply_32_loss: 3.5525 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  28
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.5274 - discriminator_loss: 14.8964 - tf.math.multiply_32_loss: 3.6310 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  29
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4477 - discriminator_loss: 14.9011 - tf.math.multiply_32_loss: 3.5466 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  30
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3875 - discriminator_loss: 14.9063 - tf.math.multiply_32_loss: 3.4812 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  31
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4554 - discriminator_loss: 14.8927 - tf.math.multiply_32_loss: 3.5627 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  32
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4420 - discriminator_loss: 14.9272 - tf.math.multiply_32_loss: 3.5148 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  33
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3424 - discriminator_loss: 14.8911 - tf.math.multiply_32_loss: 3.4512 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  34
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.5140 - discriminator_loss: 14.9064 - tf.math.multiply_32_loss: 3.6076 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  35
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3842 - discriminator_loss: 14.8796 - tf.math.multiply_32_loss: 3.5046 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  36
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4035 - discriminator_loss: 14.8836 - tf.math.multiply_32_loss: 3.5199 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  37
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4323 - discriminator_loss: 14.9001 - tf.math.multiply_32_loss: 3.5322 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  38
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4142 - discriminator_loss: 14.8926 - tf.math.multiply_32_loss: 3.5216 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  39
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4614 - discriminator_loss: 14.8895 - tf.math.multiply_32_loss: 3.5719 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  40
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4378 - discriminator_loss: 14.8862 - tf.math.multiply_32_loss: 3.5516 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  41
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3938 - discriminator_loss: 14.8742 - tf.math.multiply_32_loss: 3.5195 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  42
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4900 - discriminator_loss: 14.8971 - tf.math.multiply_32_loss: 3.5929 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  43
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3965 - discriminator_loss: 14.8802 - tf.math.multiply_32_loss: 3.5164 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  44
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4769 - discriminator_loss: 14.8975 - tf.math.multiply_32_loss: 3.5794 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  45
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3687 - discriminator_loss: 14.8814 - tf.math.multiply_32_loss: 3.4874 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  46
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4137 - discriminator_loss: 14.9064 - tf.math.multiply_32_loss: 3.5073 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  47
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3356 - discriminator_loss: 14.8806 - tf.math.multiply_32_loss: 3.4550 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  48
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3620 - discriminator_loss: 14.8668 - tf.math.multiply_32_loss: 3.4952 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  49
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3673 - discriminator_loss: 14.9001 - tf.math.multiply_32_loss: 3.4672 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  50
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4220 - discriminator_loss: 14.9179 - tf.math.multiply_32_loss: 3.5041 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  51
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3462 - discriminator_loss: 14.8961 - tf.math.multiply_32_loss: 3.4501 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  52
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4232 - discriminator_loss: 14.9003 - tf.math.multiply_32_loss: 3.5230 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  53
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4223 - discriminator_loss: 14.8941 - tf.math.multiply_32_loss: 3.5282 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  54
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4973 - discriminator_loss: 14.8789 - tf.math.multiply_32_loss: 3.6184 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  55
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3920 - discriminator_loss: 14.8939 - tf.math.multiply_32_loss: 3.4981 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  56
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3818 - discriminator_loss: 14.8823 - tf.math.multiply_32_loss: 3.4994 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  57
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.2967 - discriminator_loss: 14.8807 - tf.math.multiply_32_loss: 3.4160 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  58
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3837 - discriminator_loss: 14.8914 - tf.math.multiply_32_loss: 3.4923 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  59
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3727 - discriminator_loss: 14.8707 - tf.math.multiply_32_loss: 3.5019 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  60
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3825 - discriminator_loss: 14.9044 - tf.math.multiply_32_loss: 3.4781 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  61
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3652 - discriminator_loss: 14.8851 - tf.math.multiply_32_loss: 3.4801 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  62
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3018 - discriminator_loss: 14.9064 - tf.math.multiply_32_loss: 3.3954 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  63
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3956 - discriminator_loss: 14.8993 - tf.math.multiply_32_loss: 3.4962 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  64
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3964 - discriminator_loss: 14.8755 - tf.math.multiply_32_loss: 3.5209 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  65
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.5416 - discriminator_loss: 14.8954 - tf.math.multiply_32_loss: 3.6463 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  66
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3504 - discriminator_loss: 14.8535 - tf.math.multiply_32_loss: 3.4969 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  67
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3611 - discriminator_loss: 14.8695 - tf.math.multiply_32_loss: 3.4916 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  68
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3789 - discriminator_loss: 14.8646 - tf.math.multiply_32_loss: 3.5143 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  69
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4195 - discriminator_loss: 14.8661 - tf.math.multiply_32_loss: 3.5534 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  70
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4518 - discriminator_loss: 14.9008 - tf.math.multiply_32_loss: 3.5510 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  71
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4775 - discriminator_loss: 14.9157 - tf.math.multiply_32_loss: 3.5618 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  72
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4330 - discriminator_loss: 14.9103 - tf.math.multiply_32_loss: 3.5227 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  73
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4815 - discriminator_loss: 14.9231 - tf.math.multiply_32_loss: 3.5584 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  74
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3705 - discriminator_loss: 14.8677 - tf.math.multiply_32_loss: 3.5029 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  75
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3143 - discriminator_loss: 14.8899 - tf.math.multiply_32_loss: 3.4244 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  76
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4140 - discriminator_loss: 14.8991 - tf.math.multiply_32_loss: 3.5149 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  77
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4484 - discriminator_loss: 14.8861 - tf.math.multiply_32_loss: 3.5624 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  78
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3980 - discriminator_loss: 14.8959 - tf.math.multiply_32_loss: 3.5021 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  79
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4288 - discriminator_loss: 14.8846 - tf.math.multiply_32_loss: 3.5442 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  80
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4146 - discriminator_loss: 14.8912 - tf.math.multiply_32_loss: 3.5234 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  81
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3190 - discriminator_loss: 14.8487 - tf.math.multiply_32_loss: 3.4703 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  82
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3960 - discriminator_loss: 14.8711 - tf.math.multiply_32_loss: 3.5249 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  83
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3707 - discriminator_loss: 14.8890 - tf.math.multiply_32_loss: 3.4816 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  84
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3977 - discriminator_loss: 14.8613 - tf.math.multiply_32_loss: 3.5364 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  85
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4404 - discriminator_loss: 14.9071 - tf.math.multiply_32_loss: 3.5334 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  86
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3646 - discriminator_loss: 14.8845 - tf.math.multiply_32_loss: 3.4801 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  87
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.2647 - discriminator_loss: 14.8914 - tf.math.multiply_32_loss: 3.3733 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  88
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4678 - discriminator_loss: 14.8977 - tf.math.multiply_32_loss: 3.5702 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  89
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3890 - discriminator_loss: 14.8990 - tf.math.multiply_32_loss: 3.4900 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  90
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4027 - discriminator_loss: 14.8965 - tf.math.multiply_32_loss: 3.5062 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  91
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3596 - discriminator_loss: 14.8920 - tf.math.multiply_32_loss: 3.4676 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  92
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3648 - discriminator_loss: 14.8972 - tf.math.multiply_32_loss: 3.4676 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  93
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3386 - discriminator_loss: 14.8736 - tf.math.multiply_32_loss: 3.4650 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  94
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3151 - discriminator_loss: 14.8735 - tf.math.multiply_32_loss: 3.4415 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  95
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4327 - discriminator_loss: 14.8653 - tf.math.multiply_32_loss: 3.5674 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  96
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4489 - discriminator_loss: 14.8961 - tf.math.multiply_32_loss: 3.5527 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  97
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4820 - discriminator_loss: 14.8765 - tf.math.multiply_32_loss: 3.6055 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  98
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3870 - discriminator_loss: 14.9082 - tf.math.multiply_32_loss: 3.4788 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  99
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4352 - discriminator_loss: 14.8780 - tf.math.multiply_32_loss: 3.5572 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  100
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4391 - discriminator_loss: 14.8902 - tf.math.multiply_32_loss: 3.5489 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  101
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.2723 - discriminator_loss: 14.8799 - tf.math.multiply_32_loss: 3.3925 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  102
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3607 - discriminator_loss: 14.8867 - tf.math.multiply_32_loss: 3.4741 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  103
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4276 - discriminator_loss: 14.9015 - tf.math.multiply_32_loss: 3.5261 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  104
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3616 - discriminator_loss: 14.8659 - tf.math.multiply_32_loss: 3.4956 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  105
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3522 - discriminator_loss: 14.8731 - tf.math.multiply_32_loss: 3.4791 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  106
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4692 - discriminator_loss: 14.8697 - tf.math.multiply_32_loss: 3.5995 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  107
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3978 - discriminator_loss: 14.8924 - tf.math.multiply_32_loss: 3.5054 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  108
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4638 - discriminator_loss: 14.8848 - tf.math.multiply_32_loss: 3.5790 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  109
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4483 - discriminator_loss: 14.8987 - tf.math.multiply_32_loss: 3.5496 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  110
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.2906 - discriminator_loss: 14.8822 - tf.math.multiply_32_loss: 3.4084 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  111
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4948 - discriminator_loss: 14.8889 - tf.math.multiply_32_loss: 3.6059 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  112
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4312 - discriminator_loss: 14.9077 - tf.math.multiply_32_loss: 3.5236 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  113
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3841 - discriminator_loss: 14.8910 - tf.math.multiply_32_loss: 3.4931 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  114
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3396 - discriminator_loss: 14.8746 - tf.math.multiply_32_loss: 3.4650 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  115
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3332 - discriminator_loss: 14.8737 - tf.math.multiply_32_loss: 3.4595 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  116
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3237 - discriminator_loss: 14.8447 - tf.math.multiply_32_loss: 3.4789 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  117
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4068 - discriminator_loss: 14.9088 - tf.math.multiply_32_loss: 3.4980 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  118
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3014 - discriminator_loss: 14.8787 - tf.math.multiply_32_loss: 3.4227 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  119
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4248 - discriminator_loss: 14.9068 - tf.math.multiply_32_loss: 3.5180 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  120
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4095 - discriminator_loss: 14.9171 - tf.math.multiply_32_loss: 3.4924 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  121
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4201 - discriminator_loss: 14.8829 - tf.math.multiply_32_loss: 3.5373 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  122
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.2972 - discriminator_loss: 14.8792 - tf.math.multiply_32_loss: 3.4180 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  123
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3453 - discriminator_loss: 14.8922 - tf.math.multiply_32_loss: 3.4530 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  124
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4310 - discriminator_loss: 14.8881 - tf.math.multiply_32_loss: 3.5429 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  125
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3709 - discriminator_loss: 14.8842 - tf.math.multiply_32_loss: 3.4867 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  126
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4229 - discriminator_loss: 14.9283 - tf.math.multiply_32_loss: 3.4945 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  127
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4046 - discriminator_loss: 14.8957 - tf.math.multiply_32_loss: 3.5090 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  128
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3629 - discriminator_loss: 14.8442 - tf.math.multiply_32_loss: 3.5187 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  129
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.3500 - discriminator_loss: 14.8456 - tf.math.multiply_32_loss: 3.5044 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  130
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3136 - discriminator_loss: 14.8423 - tf.math.multiply_32_loss: 3.4713 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  131
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3167 - discriminator_loss: 14.8411 - tf.math.multiply_32_loss: 3.4757 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  132
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3573 - discriminator_loss: 14.8804 - tf.math.multiply_32_loss: 3.4768 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  133
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4781 - discriminator_loss: 14.8943 - tf.math.multiply_32_loss: 3.5837 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  134
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3970 - discriminator_loss: 14.8911 - tf.math.multiply_32_loss: 3.5059 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  135
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3542 - discriminator_loss: 14.8437 - tf.math.multiply_32_loss: 3.5104 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  136
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4464 - discriminator_loss: 14.8953 - tf.math.multiply_32_loss: 3.5511 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  137
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4567 - discriminator_loss: 14.8961 - tf.math.multiply_32_loss: 3.5606 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  138
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3490 - discriminator_loss: 14.8485 - tf.math.multiply_32_loss: 3.5005 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  139
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.4424 - discriminator_loss: 14.8808 - tf.math.multiply_32_loss: 3.5616 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  140
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3257 - discriminator_loss: 14.8671 - tf.math.multiply_32_loss: 3.4586 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  141
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3998 - discriminator_loss: 14.8893 - tf.math.multiply_32_loss: 3.5105 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  142
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.5172 - discriminator_loss: 14.8871 - tf.math.multiply_32_loss: 3.6301 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  143
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.4612 - discriminator_loss: 14.8873 - tf.math.multiply_32_loss: 3.5740 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  144
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4168 - discriminator_loss: 14.8497 - tf.math.multiply_32_loss: 3.5670 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  145
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3611 - discriminator_loss: 14.8671 - tf.math.multiply_32_loss: 3.4941 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  146
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3336 - discriminator_loss: 14.8776 - tf.math.multiply_32_loss: 3.4561 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  147
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3410 - discriminator_loss: 14.8648 - tf.math.multiply_32_loss: 3.4763 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  148
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3732 - discriminator_loss: 14.8754 - tf.math.multiply_32_loss: 3.4978 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  149
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4706 - discriminator_loss: 14.8900 - tf.math.multiply_32_loss: 3.5806 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  150
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3712 - discriminator_loss: 14.8681 - tf.math.multiply_32_loss: 3.5030 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  151
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.2579 - discriminator_loss: 14.8518 - tf.math.multiply_32_loss: 3.4060 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  152
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.5111 - discriminator_loss: 14.8810 - tf.math.multiply_32_loss: 3.6302 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  153
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3614 - discriminator_loss: 14.8862 - tf.math.multiply_32_loss: 3.4752 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  154
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4432 - discriminator_loss: 14.9093 - tf.math.multiply_32_loss: 3.5338 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  155
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3873 - discriminator_loss: 14.8781 - tf.math.multiply_32_loss: 3.5092 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  156
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4858 - discriminator_loss: 14.8804 - tf.math.multiply_32_loss: 3.6054 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  157
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4077 - discriminator_loss: 14.8919 - tf.math.multiply_32_loss: 3.5158 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  158
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3214 - discriminator_loss: 14.9019 - tf.math.multiply_32_loss: 3.4194 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  159
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.4191 - discriminator_loss: 14.8708 - tf.math.multiply_32_loss: 3.5483 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  160
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3175 - discriminator_loss: 14.8519 - tf.math.multiply_32_loss: 3.4657 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  161
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4520 - discriminator_loss: 14.8754 - tf.math.multiply_32_loss: 3.5766 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  162
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3256 - discriminator_loss: 14.8598 - tf.math.multiply_32_loss: 3.4658 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  163
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 43ms/step - loss: 18.4046 - discriminator_loss: 14.8613 - tf.math.multiply_32_loss: 3.5432 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  164
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.4977 - discriminator_loss: 14.8924 - tf.math.multiply_32_loss: 3.6053 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  165
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.5167 - discriminator_loss: 14.8820 - tf.math.multiply_32_loss: 3.6347 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  166
# ...
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3125 - discriminator_loss: 14.8731 - tf.math.multiply_32_loss: 3.4394 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  447
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3298 - discriminator_loss: 14.8535 - tf.math.multiply_32_loss: 3.4762 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  448
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3559 - discriminator_loss: 14.8847 - tf.math.multiply_32_loss: 3.4713 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  449
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.2826 - discriminator_loss: 14.8510 - tf.math.multiply_32_loss: 3.4316 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  450
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3174 - discriminator_loss: 14.8574 - tf.math.multiply_32_loss: 3.4601 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  451
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3005 - discriminator_loss: 14.8734 - tf.math.multiply_32_loss: 3.4271 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  452
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2632 - discriminator_loss: 14.8591 - tf.math.multiply_32_loss: 3.4041 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  453
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2853 - discriminator_loss: 14.8615 - tf.math.multiply_32_loss: 3.4238 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  454
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3645 - discriminator_loss: 14.8632 - tf.math.multiply_32_loss: 3.5014 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  455
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3266 - discriminator_loss: 14.8716 - tf.math.multiply_32_loss: 3.4550 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  456
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3970 - discriminator_loss: 14.8635 - tf.math.multiply_32_loss: 3.5335 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  457
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.3844 - discriminator_loss: 14.8740 - tf.math.multiply_32_loss: 3.5103 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  458
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3117 - discriminator_loss: 14.8521 - tf.math.multiply_32_loss: 3.4595 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  459
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.2706 - discriminator_loss: 14.8566 - tf.math.multiply_32_loss: 3.4140 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  460
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2250 - discriminator_loss: 14.8212 - tf.math.multiply_32_loss: 3.4038 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  461
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3245 - discriminator_loss: 14.8340 - tf.math.multiply_32_loss: 3.4904 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  462
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2569 - discriminator_loss: 14.8413 - tf.math.multiply_32_loss: 3.4157 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  463
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3301 - discriminator_loss: 14.8236 - tf.math.multiply_32_loss: 3.5066 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  464
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3620 - discriminator_loss: 14.8430 - tf.math.multiply_32_loss: 3.5190 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  465
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3370 - discriminator_loss: 14.8458 - tf.math.multiply_32_loss: 3.4911 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  466
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3226 - discriminator_loss: 14.8433 - tf.math.multiply_32_loss: 3.4793 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  467
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3296 - discriminator_loss: 14.8296 - tf.math.multiply_32_loss: 3.5000 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  468
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.4181 - discriminator_loss: 14.8522 - tf.math.multiply_32_loss: 3.5660 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  469
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.3691 - discriminator_loss: 14.8532 - tf.math.multiply_32_loss: 3.5159 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  470
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3241 - discriminator_loss: 14.8360 - tf.math.multiply_32_loss: 3.4881 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  471
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3025 - discriminator_loss: 14.8478 - tf.math.multiply_32_loss: 3.4547 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  472
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3251 - discriminator_loss: 14.8432 - tf.math.multiply_32_loss: 3.4819 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  473
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3831 - discriminator_loss: 14.8503 - tf.math.multiply_32_loss: 3.5328 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  474
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2900 - discriminator_loss: 14.8179 - tf.math.multiply_32_loss: 3.4721 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  475
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3051 - discriminator_loss: 14.8497 - tf.math.multiply_32_loss: 3.4553 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  476
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2490 - discriminator_loss: 14.8250 - tf.math.multiply_32_loss: 3.4241 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  477
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2609 - discriminator_loss: 14.8327 - tf.math.multiply_32_loss: 3.4283 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  478
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3908 - discriminator_loss: 14.8433 - tf.math.multiply_32_loss: 3.5475 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  479
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3752 - discriminator_loss: 14.8715 - tf.math.multiply_32_loss: 3.5037 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  480
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3198 - discriminator_loss: 14.8259 - tf.math.multiply_32_loss: 3.4939 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  481
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3679 - discriminator_loss: 14.8645 - tf.math.multiply_32_loss: 3.5034 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  482
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3761 - discriminator_loss: 14.8466 - tf.math.multiply_32_loss: 3.5296 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  483
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3627 - discriminator_loss: 14.8530 - tf.math.multiply_32_loss: 3.5097 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  484
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.1951 - discriminator_loss: 14.8490 - tf.math.multiply_32_loss: 3.3461 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  485
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3488 - discriminator_loss: 14.8321 - tf.math.multiply_32_loss: 3.5167 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  486
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3619 - discriminator_loss: 14.8611 - tf.math.multiply_32_loss: 3.5008 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  487
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.3807 - discriminator_loss: 14.8717 - tf.math.multiply_32_loss: 3.5089 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  488
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.2028 - discriminator_loss: 14.8084 - tf.math.multiply_32_loss: 3.3944 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  489
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3628 - discriminator_loss: 14.8311 - tf.math.multiply_32_loss: 3.5317 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  490
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.3168 - discriminator_loss: 14.8444 - tf.math.multiply_32_loss: 3.4723 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  491
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3485 - discriminator_loss: 14.8522 - tf.math.multiply_32_loss: 3.4963 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  492
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2514 - discriminator_loss: 14.8473 - tf.math.multiply_32_loss: 3.4041 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  493
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.3330 - discriminator_loss: 14.8498 - tf.math.multiply_32_loss: 3.4833 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  494
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.3310 - discriminator_loss: 14.8617 - tf.math.multiply_32_loss: 3.4693 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  495
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3887 - discriminator_loss: 14.8638 - tf.math.multiply_32_loss: 3.5249 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  496
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 46ms/step - loss: 18.3139 - discriminator_loss: 14.8407 - tf.math.multiply_32_loss: 3.4733 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  497
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3659 - discriminator_loss: 14.8646 - tf.math.multiply_32_loss: 3.5013 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  498
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.2537 - discriminator_loss: 14.8657 - tf.math.multiply_32_loss: 3.3881 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  499
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 45ms/step - loss: 18.4671 - discriminator_loss: 14.8574 - tf.math.multiply_32_loss: 3.6097 - discriminator_binary_accuracy: 0.0000e+00
# Epoch:  500
# Generator accuracy is less than 50%, skipping discriminator training for current epoch
# Training Gan
# 32/32 [==============================] - 1s 44ms/step - loss: 18.3083 - discriminator_loss: 14.8538 - tf.math.multiply_32_loss: 3.4545 - discriminator_binary_accuracy: 0.0000e+00

# %%
tf.keras.models.save_model(gan.model, os.path.join(gan.model_params['save_dir'], gan.model_name))
# Out:
# INFO:tensorflow:Assets written to: Flute_Classifier/flute_v1/assets
